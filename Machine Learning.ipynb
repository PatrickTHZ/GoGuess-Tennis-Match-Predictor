# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
matches3 = pd.read_csv('matches3.csv')
matches3
# Out:
#        player_1_h2h  player_2_h2h                       tourney_id  \
# 0               0.0           0.0                         2015-403
# 1               0.0           1.0                         2015-403
# 2               1.0           0.0                         2015-403
# 3               0.0           0.0                         2015-403
# 4               0.0           0.0                         2015-403
# ...             ...           ...                              ...
# 14324           0.0           0.0  2022-M-DC-2022-WG1-M-ECU-SUI-01
# 14325           0.0           0.0  2022-M-DC-2022-WG1-M-ECU-SUI-01
# 14326           0.0           0.0  2022-M-DC-2022-WG1-M-IND-NOR-01
# 14327           0.0           0.0  2022-M-DC-2022-WG1-M-SVK-ROU-01
# 14328           0.0           0.0  2022-M-DC-2022-WG2-M-LTU-EGY-01
#
#                        tourney_name surface  draw_size tourney_level  \
# 0                     Miami Masters    Hard         96             M
# 1                     Miami Masters    Hard         96             M
# 2                     Miami Masters    Hard         96             M
# 3                     Miami Masters    Hard         96             M
# 4                     Miami Masters    Hard         96             M
# ...                             ...     ...        ...           ...
# 14324  Davis Cup WG1 R1: ECU vs SUI    Hard          4             D
# 14325  Davis Cup WG1 R1: ECU vs SUI    Hard          4             D
# 14326  Davis Cup WG1 R1: IND vs NOR    Hard          4             D
# 14327  Davis Cup WG1 R1: SVK vs ROU    Clay          4             D
# 14328  Davis Cup WG2 R1: LTU vs EGY    Hard          4             D
#
#       tourney_date  match_num        score  ...  player_1_level_win_pct  \
# 0       2015-03-25         69      6-2 6-2  ...                0.750000
# 1       2015-03-25         77  6-7 7-6 6-1  ...                0.750000
# 2       2015-03-25         82      7-6 6-0  ...                0.750000
# 3       2015-03-25         86  6-4 3-6 6-3  ...                0.857143
# 4       2015-03-25         89      7-5 7-5  ...                0.600000
# ...            ...        ...          ...  ...                     ...
# 14324   2022-09-17          2      6-4 6-3  ...                0.571429
# 14325   2022-09-17          4  6-7 6-2 6-2  ...                0.600000
# 14326   2022-09-16          1      6-1 6-4  ...                0.785714
# 14327   2022-09-16          2      7-5 6-1  ...                0.000000
# 14328   2022-09-17          4      6-2 6-1  ...                0.583333
#
#       player_2_level_win_pct  h2h_diff  recent_form_diff  surface_diff  \
# 0                   0.000000       0.0          0.144570      0.126087
# 1                   0.800000      -1.0         -0.076719     -0.069231
# 2                   0.600000       1.0          0.289168      0.222222
# 3                   0.500000       0.0          0.215676      0.181818
# 4                   1.000000       0.0         -0.047923     -0.074561
# ...                      ...       ...               ...           ...
# 14324               0.450000       0.0         -0.023860     -0.083333
# 14325               0.250000       0.0         -0.023810     -0.121212
# 14326               0.222222       0.0          0.652759      0.319688
# 14327               0.600000       0.0          0.352880      0.567308
# 14328               0.866667       0.0         -0.112584     -0.331228
#
#        level_diff  log_player_1_rank  log_player_2_rank  log_rank_ratio  \
# 0        0.126087           1.609438           3.663562       -2.054124
# 1       -0.069231           3.367296           2.197225        1.170071
# 2        0.242424           1.945910           2.639057       -0.693147
# 3        0.181818           1.386294           2.833213       -1.446919
# 4       -0.047101           1.945910           0.000000        1.945910
# ...           ...                ...                ...             ...
# 14324   -0.023860           4.718499           4.812184       -0.093685
# 14325   -0.023810           4.718499           4.465908        0.252591
# 14326    0.413536           0.693147           5.814131       -5.120983
# 14327    0.152520           3.806662           5.849325       -2.042662
# 14328   -0.112584           6.472346           4.787492        1.684855
#
#        age_diff
# 0          -3.9
# 1          -7.1
# 2           2.7
# 3          -1.0
# 4           5.1
# ...         ...
# 14324       0.3
# 14325       4.5
# 14326      -9.1
# 14327      -7.2
# 14328      -0.3
#
# [14329 rows x 84 columns]

# %%
X = matches3[['player_1_age',
              'player_2_age',
              'log_player_1_rank',
              'log_player_2_rank',
              'player_1_h2h',
              'player_2_h2h',
              'player_1_recent_form',
              'player_2_recent_form',
              'player_1_surface_win_pct',
              'player_2_surface_win_pct',
              'player_1_level_win_pct',
              'player_2_level_win_pct',
              'surface',
              'tourney_level'
             ]]

y = matches3['target']

# %%
X
# Out:
#        player_1_age  player_2_age  log_player_1_rank  log_player_2_rank  \
# 0              25.2          29.1           1.609438           3.663562
# 1              22.4          29.5           3.367296           2.197225
# 2              32.9          30.2           1.945910           2.639057
# 3              27.8          28.8           1.386294           2.833213
# 4              32.9          27.8           1.945910           0.000000
# ...             ...           ...                ...                ...
# 14324          30.7          30.4           4.718499           4.812184
# 14325          30.7          26.2           4.718499           4.465908
# 14326          23.7          32.8           0.693147           5.814131
# 14327          24.7          31.9           3.806662           5.849325
# 14328          31.9          32.2           6.472346           4.787492
#
#        player_1_h2h  player_2_h2h  player_1_recent_form  player_2_recent_form  \
# 0               0.0           0.0              1.087608              0.943038
# 1               0.0           1.0              0.978554              1.055273
# 2               1.0           0.0              1.189918              0.900750
# 3               0.0           0.0              1.077819              0.862143
# 4               0.0           0.0              1.151290              1.199213
# ...             ...           ...                   ...                   ...
# 14324           0.0           0.0              0.370370              0.394231
# 14325           0.0           0.0              0.392857              0.416667
# 14326           0.0           0.0              0.896003              0.243243
# 14327           0.0           0.0              0.758052              0.405172
# 14328           0.0           0.0              0.320000              0.432584
#
#        player_1_surface_win_pct  player_2_surface_win_pct  \
# 0                      0.826087                  0.700000
# 1                      0.730769                  0.800000
# 2                      0.888889                  0.666667
# 3                      0.818182                  0.636364
# 4                      0.842105                  0.916667
# ...                         ...                       ...
# 14324                  0.300000                  0.383333
# 14325                  0.333333                  0.454545
# 14326                  0.578947                  0.259259
# 14327                  0.692308                  0.125000
# 14328                  0.153846                  0.485075
#
#        player_1_level_win_pct  player_2_level_win_pct surface tourney_level
# 0                    0.750000                0.000000    Hard             M
# 1                    0.750000                0.800000    Hard             M
# 2                    0.750000                0.600000    Hard             M
# 3                    0.857143                0.500000    Hard             M
# 4                    0.600000                1.000000    Hard             M
# ...                       ...                     ...     ...           ...
# 14324                0.571429                0.450000    Hard             D
# 14325                0.600000                0.250000    Hard             D
# 14326                0.785714                0.222222    Hard             D
# 14327                0.000000                0.600000    Clay             D
# 14328                0.583333                0.866667    Hard             D
#
# [14329 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder

# %%
mask1 = (matches3['player_1_rank'] < matches3['player_2_rank']) & (matches3['target'] == 'player_1')
mask2 = (matches3['player_2_rank'] < matches3['player_1_rank']) & (matches3['target'] == 'player_2')

matches3[mask1 | mask2].shape[0] / matches3.shape[0]
# 64.205% of matches won by higher-ranked player. Treat this as 'baseline' of success for models.
# Out:
# 0.6420545746388443

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=106)

# %%
# encode categorical variables with numbers
# this is required for ensembling techniques

lencoder = LabelEncoder()

def numer_label(DF):
   
    categ_cols = ['surface', 'tourney_level']
    
    for name in categ_cols:
        DF[name] = lencoder.fit_transform(DF[name])
    return DF

X_train_ens = X_train.copy()
X_test_ens = X_test.copy()

X_train_ens = numer_label(X_train_ens)
X_test_ens = numer_label(X_test_ens)

# %%
gbc = GradientBoostingClassifier(max_features = 'sqrt')

gs_params = {'n_estimators': [400, 800, 1200],
             'max_depth': [2, 4, 6],
             'subsample': [.7, .8, .9]}

gs = GridSearchCV(gbc, gs_params, cv = 5)

gs.fit(X_train_ens, y_train)

gbc_best = gs.best_estimator_

print(gbc_best)
print(gbc_best.score(X_train_ens, y_train))
print(gbc_best.score(X_test_ens, y_test))
# Out:
# GradientBoostingClassifier(max_depth=2, max_features='sqrt', n_estimators=400,
#                            subsample=0.7)
# 0.7464887027828666
# 0.7250523377529658

# %%
# Feature importances as determined by best gbc model

feat_imp = sorted(list(zip(X_train_ens.columns, gbc_best.feature_importances_)), key = lambda x: -x[1])

feat_imp_df = pd.DataFrame({'feature': [x[0] for x in feat_imp],
                            'importance': [x[1] for x in feat_imp]})

sns.barplot(data = feat_imp_df, x = 'feature', y = 'importance')

plt.xticks(rotation = 90)
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.title('Feature importances (gradient boosting classifier)', size = 16)
# Out:
# Text(0.5, 1.0, 'Feature importances (gradient boosting classifier)')

# %%
rfc = RandomForestClassifier(max_features = 'sqrt')

gs_params = {'n_estimators': [400, 800, 1200],
             'max_depth': [2, 4, 6]}

gs = GridSearchCV(rfc, gs_params, cv = 5)
gs.fit(X_train_ens, y_train)

rfc_best = gs.best_estimator_

rfc_best.fit(X_train_ens, y_train)

print(rfc_best)
print(rfc_best.score(X_train_ens, y_train))
print(rfc_best.score(X_test_ens, y_test)) # Improvement on baseline, slight overfitting?
# Out:
# RandomForestClassifier(max_depth=6, n_estimators=1200)
# 0.7341010206752159
# 0.7058618283321703

# %%
#feature importances as determined by rfc
#similar to gbc features importances.
#only major change is that player ages are notably less important in rfc than in gbc

feat_imp = sorted(list(zip(X_train_ens.columns, rfc_best.feature_importances_)), key = lambda x: -x[1])

feat_imp_df = pd.DataFrame({'feature': [x[0] for x in feat_imp],
                            'importance': [x[1] for x in feat_imp]})

sns.barplot(data = feat_imp_df, x = 'feature', y = 'importance')

plt.xticks(rotation = 90)
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.title('Feature importances (random forest classifier)', size = 16)
# Out:
# Text(0.5, 1.0, 'Feature importances (random forest classifier)')

# %%
X_train_log = X_train.copy()
X_train_log = pd.get_dummies(X_train_log, drop_first = True)

X_test_log = X_test.copy()
X_test_log = pd.get_dummies(X_test_log, drop_first = True)

# %%
logit = LogisticRegression(solver='liblinear')

gs_params = {'C': 10**np.linspace(-2, 2, 26)}
gs = GridSearchCV(logit, gs_params, cv = 5)

gs.fit(X_train_log, y_train)

log_best = gs.best_estimator_

print(log_best)
print(log_best.score(X_train_log, y_train))
print(log_best.score(X_test_log, y_test)) #improvement on baseline, no overfitting
# Out:
# LogisticRegression(C=3.630780547701014, solver='liblinear')
# 0.725900724068743
# 0.7222609909281228

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
lda = LinearDiscriminantAnalysis()

# %%
lda.fit(X_train_ens, y_train)
# Out:
# LinearDiscriminantAnalysis()

# %% [markdown]
# LinearDiscriminantAnalysis()

# %%
print(lda.score(X_train_ens, y_train))
print(lda.score(X_test_ens, y_test)) #improvement on baseline, best model so far
# Out:
# 0.7242432173078601
# 0.7229588276343336

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb.fit(X_train_ens, y_train)
print(gnb.score(X_train_ens, y_train))
print(gnb.score(X_test_ens, y_test)) #small improvement on baseline
# Out:
# 0.7014743086452063
# 0.6912072575017446

# %%
# Want to examine the performance of the best model (gradient boosting classifier) more in-depth

# Specifically, want to study the case when the lower-ranked player is correctly chosen as the winner

gbc_predictions = gbc_best.predict(X_test_ens)

pred_rows = matches3.loc[y_test.index].copy()
pred_rows['prediction'] = gbc_predictions

pred_rows = pred_rows[['surface',
                       'tourney_level',
                       'target', 
                       'prediction',
                       'player_1_rank',
                       'player_2_rank',
                       'player_1_h2h',
                       'player_2_h2h',
                       'player_1_recent_form',
                       'player_2_recent_form',
                       'player_1_surface_win_pct',
                       'player_2_surface_win_pct',
                       'player_1_level_win_pct',
                       'player_2_level_win_pct']]

pred_rows['correct'] = pred_rows['target'] == pred_rows['prediction']

mask1 = (pred_rows['target'] == 'player_1') & (pred_rows['player_1_rank'] > pred_rows['player_2_rank'])
mask2 = (pred_rows['target'] == 'player_2') & (pred_rows['player_1_rank'] < pred_rows['player_2_rank'])
pred_rows['lower_ranked_won'] = mask1 | mask2
pred_rows
# Out:
#       surface tourney_level    target prediction  player_1_rank  \
# 520      Hard             G  player_2   player_2           55.0
# 10726    Hard             A  player_2   player_2           29.0
# 2032     Hard             A  player_1   player_2           35.0
# 4784     Hard             A  player_1   player_1            6.0
# 13421   Grass             G  player_1   player_1           58.0
# ...       ...           ...       ...        ...            ...
# 12619    Hard             M  player_2   player_2           19.0
# 3506     Clay             A  player_1   player_1           20.0
# 12152    Hard             A  player_1   player_1           92.0
# 2092     Hard             A  player_2   player_1           29.0
# 8907     Hard             M  player_1   player_1           35.0
#
#        player_2_rank  player_1_h2h  player_2_h2h  player_1_recent_form  \
# 520             26.0           0.0           0.0              0.614706
# 10726           67.0           0.0           1.0              0.753857
# 2032            26.0           1.0           0.0              0.790481
# 4784            81.0           0.0           0.0              0.881535
# 13421           35.0           0.0           0.0              0.822489
# ...              ...           ...           ...                   ...
# 12619            4.0           0.0           1.0              0.959816
# 3506           158.0           0.0           0.0              0.823670
# 12152          103.0           0.0           0.0              0.402778
# 2092           137.0           1.0           0.0              0.747249
# 8907             9.0           0.0           0.0              0.869308
#
#        player_2_recent_form  player_1_surface_win_pct  \
# 520                0.759183                  0.416667
# 10726              0.914925                  0.510417
# 2032               0.841548                  0.583333
# 4784               0.387097                  0.641667
# 13421              0.747191                  0.656250
# ...                     ...                       ...
# 12619              1.137664                  0.685714
# 3506               0.400000                  0.647059
# 12152              0.400000                  0.451613
# 2092               0.432836                  0.500000
# 8907               0.832038                  0.687943
#
#        player_2_surface_win_pct  player_1_level_win_pct  \
# 520                    0.583333                0.428571
# 10726                  0.698020                0.568807
# 2032                   0.644444                0.661017
# 4784                   0.404762                0.697674
# 13421                  0.333333                0.675325
# ...                         ...                     ...
# 12619                  0.807339                0.500000
# 3506                   0.451613                0.644737
# 12152                  0.461538                0.404255
# 2092                   0.315789                0.584906
# 8907                   0.489362                0.574074
#
#        player_2_level_win_pct  correct  lower_ranked_won
# 520                  0.500000     True             False
# 10726                0.750000     True              True
# 2032                 0.722222    False              True
# 4784                 0.466667     True             False
# 13421                0.400000     True              True
# ...                       ...      ...               ...
# 12619                0.816327     True             False
# 3506                 0.437500     True             False
# 12152                0.352941     True             False
# 2092                 0.476190    False              True
# 8907                 0.375000     True              True
#
# [2866 rows x 16 columns]

# %%
pred_rows.groupby('lower_ranked_won').agg({'correct': 'mean'}).reset_index()

# Prediction accuracy for matches where the higher ranked player won
# and where the lower ranked player won
# Out:
#    lower_ranked_won   correct
# 0             False  0.857843
# 1              True  0.488350

# %%
surfaces_accuracy = pred_rows.groupby(['surface', 'lower_ranked_won']).agg({'correct': 'mean'}).reset_index()
surfaces_accuracy
# Out:
#   surface  lower_ranked_won   correct
# 0    Clay             False  0.845714
# 1    Clay              True  0.498403
# 2   Grass             False  0.846939
# 3   Grass              True  0.560748
# 4    Hard             False  0.865471
# 5    Hard              True  0.470492

# %%
sns.catplot(data = surfaces_accuracy,
            x = 'surface',
            y = 'correct',
            hue = 'lower_ranked_won',
            kind = 'bar',
            legend = False,
            height = 5,
            aspect = 1.3)

plt.title('Prediction accuracy by surface for GBC model', size = 16)
plt.legend(title = 'Lower ranked player won', loc = 'lower right')
plt.xlabel('Surface')
plt.ylabel('Prediction accuracy')
# Out:
# Text(9.444444444444452, 0.5, 'Prediction accuracy')

# %%
levels_accuracy = pred_rows.groupby(['tourney_level', 'lower_ranked_won']).agg({'correct': 'mean'}).reset_index()
levels_accuracy
# Out:
#   tourney_level  lower_ranked_won   correct
# 0             A             False  0.831942
# 1             A              True  0.492659
# 2             D             False  0.928571
# 3             D              True  0.642857
# 4             F             False  0.785714
# 5             F              True  0.588235
# 6             G             False  0.881748
# 7             G              True  0.557047
# 8             M             False  0.887828
# 9             M              True  0.403587

# %%
plot =  sns.catplot(data = levels_accuracy,
                    x = 'tourney_level',
                    y = 'correct',
                    hue = 'lower_ranked_won',
                    kind = 'bar',
                    order = ['A','F', 'D', 'G', 'M'],
                    height = 5,
                    aspect = 2.5)
plot.set_xticklabels(['other tour-level events', 'Tour finals',
                      'Davis Cup', 'Grand Slams',
                      'Masters 1000s'])

plt.title('Prediction accuracy by tournament level for GBC model', size = 16)
plt.legend(title = 'Lower ranked player won', loc = 'lower right')
plt.xlabel('Tournament Level')
plt.ylabel('Prediction accuracy')
# Out:
# Text(33.306394135802485, 0.5, 'Prediction accuracy')

# %%
# At G/D/F tournaments, correctly guess winner 77% of the time
# This is due to an increase in predictive accuracy for matches in which the higher-ranked player won
# What are reasons for this increase?

total = pred_rows[pred_rows['tourney_level'].isin(['C', 'G', 'D'])].shape[0]
correct = pred_rows[pred_rows['tourney_level'].isin(['C', 'D','G']) & (pred_rows['correct'] == True)].shape[0]
correct / total
# Out:
# 0.797427652733119

# %%
total = pred_rows[~pred_rows['tourney_level'].isin(['C', 'G', 'D'])].shape[0]
correct = pred_rows[(~pred_rows['tourney_level'].isin(['C', 'O', 'D'])) & (pred_rows['correct'] == True)].shape[0]
correct / total
# Out:
# 0.8948306595365418

# %%
pred_rows['winner_level_diff'] = ((pred_rows['player_1_level_win_pct']
                                   - pred_rows['player_2_level_win_pct'])
                                  *(-1+2*(pred_rows['target']=='player_1')))

pred_rows['winner_surface_diff'] = ((pred_rows['player_1_surface_win_pct']
                                     - pred_rows['player_2_surface_win_pct'])
                                    *(-1+2*(pred_rows['target']=='player_1')))

pred_rows['winner_form_diff'] = ((pred_rows['player_1_recent_form']
                                  - pred_rows['player_2_recent_form'])
                                 *(-1+2*(pred_rows['target']=='player_1')))

# %%
# What explains the increase in predictive accuracy for C, D, G for matches won by lower-ranked players?

# For these four tournament levels, the distributions are right-skewed, while the other tournaments are
# more symmetrical. Tournament level win % is a more effective predictor for these levels
grid = sns.FacetGrid(data = pred_rows, col = 'tourney_level', col_wrap = 4, sharey = False)
grid.map(sns.histplot, 'winner_level_diff', color = '#00AD9B', kde = False, bins = 15)

grid.fig.suptitle('Difference between tourament level win percents (winner - loser)', size = 16)
grid.fig.subplots_adjust(top=.875)

# %%
pred_rows.groupby('tourney_level')['winner_level_diff'].mean()
# Out:
# tourney_level
# A    0.061768
# D    0.253469
# F    0.316148
# G    0.188941
# M    0.118120
# Name: winner_level_diff, dtype: float64

# %%
pred_rows[pred_rows['tourney_level']=='G']['winner_level_diff']
# Out:
# 520      0.071429
# 13421    0.275325
# 11405   -0.168750
# 6373    -0.015121
# 8515     0.526316
#            ...
# 11409   -0.126797
# 12290    0.033684
# 2296     0.125000
# 6029     0.166667
# 13175   -0.075630
# Name: winner_level_diff, Length: 538, dtype: float64

# %%
# For F, there is little variation in ranking, so other features have more predictive power

from scipy.stats import iqr
D = pred_rows[pred_rows['tourney_level'] == 'D']['player_1_rank']
print('Fed Cup:', 'Standard deviation', D.std())

C = pred_rows[pred_rows['tourney_level'] == 'C']['player_1_rank']
print('Challenger:', 'Standard deviation', C.std())

F = pred_rows[pred_rows['tourney_level'] == 'F']['player_1_rank']
print('ATP Finals:', 'Standard deviation', F.std())
# Out:
# Fed Cup: Standard deviation 61.40126362694546
# Challenger: Standard deviation nan
# ATP Finals: Standard deviation 23.78786172801998

# %%
all_ranks = pd.concat([pred_rows['player_1_rank'], pred_rows['player_2_rank']])
cutoffs = np.insert(np.quantile(all_ranks, np.linspace(.1,1,10)), 0, 0)

# %%
pred_rows['player_1_bins'] = pd.cut(pred_rows['player_1_rank'],
                                    bins = cutoffs)

pred_rows['player_2_bins'] = pd.cut(pred_rows['player_2_rank'],
                                    bins = cutoffs)

# %%
pred_rows['log_rank_ratio'] = np.abs(np.log(pred_rows['player_1_rank']/np.abs(pred_rows['player_2_rank'])))
pred_rows['log_rank_ratio'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
pred_rows.groupby('tourney_level')['log_rank_ratio'].mean()
# Out:
# tourney_level
# A    0.937616
# D    1.082788
# F    0.644751
# G    1.421303
# M    1.201112
# Name: log_rank_ratio, dtype: float64

# %%
pred_rows.groupby('tourney_level')['winner_level_diff'].mean()
# Out:
# tourney_level
# A    0.061768
# D    0.253469
# F    0.316148
# G    0.188941
# M    0.118120
# Name: winner_level_diff, dtype: float64

# %%
from scipy.stats import ttest_1samp

for surface in pred_rows['tourney_level'].unique():
    print(surface,
          ttest_1samp(pred_rows[pred_rows['tourney_level'] == surface]['winner_level_diff'],
                      popmean = 0)[1])
# Out:
# G 5.782337937085702e-51
# A 1.1082615748678439e-51
# M 1.0879683747416737e-36
# D 2.0652979796537028e-08
# F 0.000752086231126126

# %%
grid = sns.FacetGrid(data = pred_rows, col = 'tourney_level', col_wrap = 4, sharey = False)
grid.map(sns.histplot, 'log_rank_ratio', color = '#00AD9B', kde = False, bins = 15)

grid.fig.suptitle('Difference between log of players\' rankings', size = 16)
grid.fig.subplots_adjust(top=.875)

# %%
rank_diffs = matches3[['tourney_level', 'log_rank_ratio']].copy()
rank_diffs['log_rank_ratio'] = np.abs(rank_diffs['log_rank_ratio'])
rank_diffs.groupby('tourney_level').agg('mean')

# F tournament has lowest variation in player rank
# Out:
#                log_rank_ratio
# tourney_level
# A                    0.960778
# D                    1.171335
# F                    0.828726
# G                    1.388558
# M                    1.174290

# %%
gps = pred_rows.groupby(['player_1_bins', 'player_2_bins'])

mean_by_bin = gps.agg({'lower_ranked_won': ['mean', 'size']}).reset_index()

mean_by_bin = mean_by_bin.dropna(how = 'any', axis = 0)
mean_by_bin = mean_by_bin.sort_values(by = ('lower_ranked_won', 'mean'),
                                      axis = 0,
                                      ascending = False)

mean_by_bin.head(20)

# Unsurprisingly, in matches where players' rankings are relatively close, the lower-ranked player
# has a higher chance of winning
# This scenario occurs most frequently in F.
# Out:
#       player_1_bins    player_2_bins lower_ranked_won
#                                                  mean size
# 75     (68.0, 84.0]     (45.0, 56.0]         0.692308   26
# 11      (8.0, 16.2]      (8.0, 16.2]         0.692308   13
# 12      (8.0, 16.2]     (16.2, 26.0]         0.578947   38
# 65     (56.0, 68.0]     (45.0, 56.0]         0.576923   26
# 55     (45.0, 56.0]     (45.0, 56.0]         0.555556   36
# 67     (56.0, 68.0]     (68.0, 84.0]         0.540541   37
# 54     (45.0, 56.0]     (35.0, 45.0]         0.526316   19
# 74     (68.0, 84.0]     (35.0, 45.0]         0.521739   23
# 87    (84.0, 107.0]     (68.0, 84.0]         0.517241   29
# 99  (107.0, 1085.0]  (107.0, 1085.0]         0.511628   43
# 43     (35.0, 45.0]     (26.0, 35.0]         0.500000   28
# 63     (56.0, 68.0]     (26.0, 35.0]         0.500000   20
# 68     (56.0, 68.0]    (84.0, 107.0]         0.500000   24
# 32     (26.0, 35.0]     (16.2, 26.0]         0.486486   37
# 85    (84.0, 107.0]     (45.0, 56.0]         0.481481   27
# 86    (84.0, 107.0]     (56.0, 68.0]         0.481481   27
# 22     (16.2, 26.0]     (16.2, 26.0]         0.476190   21
# 77     (68.0, 84.0]     (68.0, 84.0]         0.472222   36
# 42     (35.0, 45.0]     (16.2, 26.0]         0.470588   34
# 89    (84.0, 107.0]  (107.0, 1085.0]         0.464286   28

# %%
mean_by_bin.tail(20)
# Out:
#       player_1_bins    player_2_bins lower_ranked_won
#                                                  mean size
# 14      (8.0, 16.2]     (35.0, 45.0]         0.250000   28
# 92  (107.0, 1085.0]     (16.2, 26.0]         0.250000   32
# 4        (0.0, 8.0]     (35.0, 45.0]         0.227273   22
# 30     (26.0, 35.0]       (0.0, 8.0]         0.226415   53
# 81    (84.0, 107.0]      (8.0, 16.2]         0.214286   14
# 9        (0.0, 8.0]  (107.0, 1085.0]         0.210526   19
# 91  (107.0, 1085.0]      (8.0, 16.2]         0.208333   24
# 5        (0.0, 8.0]     (45.0, 56.0]         0.200000   20
# 15      (8.0, 16.2]     (45.0, 56.0]         0.200000   30
# 80    (84.0, 107.0]       (0.0, 8.0]         0.181818   11
# 41     (35.0, 45.0]      (8.0, 16.2]         0.178571   28
# 90  (107.0, 1085.0]       (0.0, 8.0]         0.157895   19
# 8        (0.0, 8.0]    (84.0, 107.0]         0.142857   28
# 70     (68.0, 84.0]       (0.0, 8.0]         0.133333   15
# 61     (56.0, 68.0]      (8.0, 16.2]         0.115385   26
# 2        (0.0, 8.0]     (16.2, 26.0]         0.108108   37
# 93  (107.0, 1085.0]     (26.0, 35.0]         0.105263   19
# 50     (45.0, 56.0]       (0.0, 8.0]         0.105263   38
# 60     (56.0, 68.0]       (0.0, 8.0]         0.090909   22
# 7        (0.0, 8.0]     (68.0, 84.0]         0.045455   22

# %%
#End by looking at some interesting examples of when the model worked well and when it didn't work well.

pred_rows_whole = matches3.loc[pred_rows.index].copy()

# %%
pred_rows_whole['correct'] = pred_rows['correct'].copy()
pred_rows_whole['lower_ranked_won'] = pred_rows['lower_ranked_won'].copy()

# %%
mask_correct = ((pred_rows_whole['correct'] == True) 
                & (pred_rows_whole['lower_ranked_won'] == True))
mask_incorrect = ((pred_rows_whole['correct'] == False) 
                  & (pred_rows_whole['lower_ranked_won'] == False))
pd.set_option('display.max_rows', 500)

# %%
pred_rows_whole[mask_correct][['tourney_name',
                               'tourney_date',
                               'player_1_name',
                               'player_1_rank',
                               'player_2_name',
                               'player_2_rank',
                               'winner'
                              ]].sort_values(by = 'tourney_date', axis = 0)

# notable examples:
#    [22203, 15132, 20126, 52226]
# Out:
#          tourney_name tourney_date          player_1_name  player_1_rank  \
# 31     Madrid Masters   2015-05-03         Kevin Anderson           17.0
# 29     Madrid Masters   2015-05-03          Jeremy Chardy           32.0
# 87               Nice   2015-05-17    Alexandr Dolgopolov           68.0
# 117     Roland Garros   2015-05-24           David Goffin           18.0
# 95      Roland Garros   2015-05-24    Alexandr Dolgopolov           69.0
# ...               ...          ...                    ...            ...
# 14134           Basel   2022-10-24            Alex Molcan           46.0
# 14227   Paris Masters   2022-10-31            Alex Molcan           44.0
# 14237  NextGen Finals   2022-11-07            Jack Draper           41.0
# 14248     Tour Finals   2022-11-14          Andrey Rublev            7.0
# 14246     Tour Finals   2022-11-14  Felix Auger Aliassime            6.0
#
#             player_2_name  player_2_rank               winner
# 31         Simone Bolelli           63.0       Simone Bolelli
# 29        Thomaz Bellucci           77.0      Thomaz Bellucci
# 87      Sergiy Stakhovsky           52.0  Alexandr Dolgopolov
# 117         Jeremy Chardy           45.0        Jeremy Chardy
# 95        Nicolas Almagro          154.0      Nicolas Almagro
# ...                   ...            ...                  ...
# 14134  Arthur Rinderknech           51.0   Arthur Rinderknech
# 14227     Richard Gasquet           76.0      Richard Gasquet
# 14237     Lorenzo Musetti           23.0          Jack Draper
# 14248  Stefanos Tsitsipas            3.0        Andrey Rublev
# 14246        Taylor Fritz            9.0         Taylor Fritz
#
# [503 rows x 7 columns]

# %%
pred_rows_whole[mask_incorrect][['tourney_name',
                                 'tourney_date',
                                 'player_1_name',
                                 'player_1_rank',
                                 'player_2_name',
                                 'player_2_rank',
                                 'winner'
                                ]].sort_values(by = 'tourney_date', axis = 0)

# notable examples:
#    [36997, 37584, 39176, 51064]
# Out:
#                        tourney_name tourney_date                player_1_name  \
# 91                             Nice   2015-05-17                  Borna Coric
# 89                             Nice   2015-05-17                  Juan Monaco
# 176                      Nottingham   2015-06-21            Sergiy Stakhovsky
# 295                         Atlanta   2015-07-27                   John Isner
# 375                  Canada Masters   2015-08-10                 Ivo Karlovic
# 429              Cincinnati Masters   2015-08-16             Adrian Mannarino
# 487                   Winston-Salem   2015-08-23                  Borna Coric
# 485                   Winston-Salem   2015-08-23                  Jiri Vesely
# 483                   Winston-Salem   2015-08-23          Pablo Carreno Busta
# 504                         US Open   2015-08-31              Benjamin Becker
# 497                         US Open   2015-08-31                Fabio Fognini
# 564     Davis Cup WG PO: RUS vs ITA   2015-09-18               Simone Bolelli
# 595                  St. Petersburg   2015-09-21                   Joao Sousa
# 740                       Stockholm   2015-10-19                Jeremy Chardy
# 1172                       Acapulco   2016-02-22          Alexandr Dolgopolov
# 1324                  Miami Masters   2016-03-21                   Joao Sousa
# 1489                       Istanbul   2016-04-25                Dusan Lajovic
# 1495                       Istanbul   2016-04-25                 Ivo Karlovic
# 1535                 Madrid Masters   2016-05-02              Feliciano Lopez
# 1542                 Madrid Masters   2016-05-02                Lucas Pouille
# 1631                         Geneva   2016-05-16                 David Ferrer
